# %% [markdown]
# # Análisis de Datos Faltantes

# %%
# Librerias
import janitor
import matplotlib.pyplot as plt
import missingno
import numpy as np
import pandas as pd
import pyreadr
import seaborn as sns
#import session_info
import upsetplot

# %%
# linea para correr el notebook utils
# %run utils.ipynb

# %% [markdown]
# ## Datos. Descarga de archivos desde una URL

# %% [markdown]
# #### 1. Creamos unidades de informacion de los conjuntos de datos

# %%
# Guardar la url en una variable
datos_url = 'https://github.com/njtierney/naniar/raw/master/data/'

# Almacenar los nombres de los archivos a descargar en una lista
datasets_names = ('oceanbuoys', 'pedestrian', 'riskfactors')

# Almacenar el tipo de extension en una variable
extension = '.rda'

# %% [markdown]
# #### 2. Descargar y cargar los conjuntos de datos

# %%
datasets_dfs = {} # diccionario que almacena los archivos descargados

for dataset_name in datasets_names:

    dataset_file = f'{ dataset_name }{ extension }' # almacena el nombre de cada archivo con su respectiva extension
    dataset_output_file = f'./data/{ dataset_file }' # ruta y nombre donde se guarda los arhcivos
    dataset_url = f'{ datos_url }{ dataset_file }' # url de cada archivo a descargar

    # !wget -q -O { dataset_output_file } { dataset_url } # linea que descarga los archivos

    # almacenar en el diccionario los archivos descargados
    datasets_dfs[f'{ dataset_name }_df'] = pyreadr.read_r(dataset_output_file).get(dataset_name)

# accede a las llaves del diccionario para verificar que los archivos se hayan cargado
datasets_dfs.keys()
# Out:
# dict_keys(['oceanbuoys_df', 'pedestrian_df', 'riskfactors_df'])

# %% [markdown]
# #### 3. Incluir conjunto de datos en nuestro ambiente local

# %%
locals().update(**datasets_dfs)
del datasets_dfs # elimina el diccionario dejando los archivos df

# %%
riskfactors_df.shape, oceanbuoys_df.shape, pedestrian_df.shape
# Out:
# ((245, 34), (736, 8), (37700, 9))

# %% [markdown]
# De esta manera podemos obtener varios archivos desde una URL y convertirlos en DataFrame para su procesamiento. El siguiente analisis de valores faltantes se haran sobre el dataframe de factores de riesgo

# %% [markdown]
# ## Resumen Basico de Valores Faltantes

# %%
# tamano del df
riskfactors_df.shape
# Out:
# (245, 34)

# %%
# Cantidad de valores en el dataframe
total = 245*34
total
# Out:
# 8330

# %%
# Cantidad de valores completos
v_completo = riskfactors_df.missing.number_complete()
v_completo
# Out:
# 7144

# %%
# Cantidad de valores faltantes
v_faltantes = riskfactors_df.missing.number_missing()
v_faltantes
# Out:
# 1186

# %%
# Porcentaje de valores faltantes en el dataframe
pct_v = (v_faltantes/v_completo)*100
pct_v
# Out:
# 16.601343784994402

# %% [markdown]
# Los calculos indican que el 16.6% de los datos son valores faltantes, lo cual puede llevar a resultados erroneos si no se toma en cuenta esta deficiencia en los datos.

# %% [markdown]
# #### Estadistica de las variables segun los datos faltantes

# %%
# Estadistica por variable de valores faltantes
riskfactors_df.missing.missing_variable_summary()
# Out:
#             variable  n_missing  n_cases  pct_missing
# 0              state          0      245     0.000000
# 1                sex          0      245     0.000000
# 2                age          0      245     0.000000
# 3         weight_lbs         10      245     4.081633
# 4        height_inch          2      245     0.816327
# 5                bmi         11      245     4.489796
# 6            marital          1      245     0.408163
# 7           pregnant        215      245    87.755102
# 8           children          0      245     0.000000
# 9          education          1      245     0.408163
# 10        employment          0      245     0.000000
# 11            income          0      245     0.000000
# 12           veteran          3      245     1.224490
# 13          hispanic          2      245     0.816327
# 14    health_general          0      245     0.000000
# 15   health_physical          0      245     0.000000
# 16     health_mental          0      245     0.000000
# 17       health_poor        113      245    46.122449
# 18      health_cover          0      245     0.000000
# 19      provide_care          3      245     1.224490
# 20  activity_limited          3      245     1.224490
# 21         drink_any          2      245     0.816327
# 22        drink_days        134      245    54.693878
# 23     drink_average        135      245    55.102041
# 24         smoke_100          2      245     0.816327
# 25        smoke_days        128      245    52.244898
# 26        smoke_stop        212      245    86.530612
# 27        smoke_last        161      245    65.714286
# 28        diet_fruit          8      245     3.265306
# 29        diet_salad          8      245     3.265306
# 30       diet_potato          8      245     3.265306
# 31       diet_carrot          8      245     3.265306
# 32    diet_vegetable          8      245     3.265306
# 33        diet_juice          8      245     3.265306

# %% [markdown]
# #### Tabla de valores faltantes sobre las variables

# %%
# Estadistica de valores faltantes sobre las variables tabuladas
riskfactors_df.missing.missing_variable_table()
# Out:
#     n_missing_in_variable  n_variables  pct_variables
# 0                       0           10      29.411765
# 1                       8            6      17.647059
# 2                       2            4      11.764706
# 3                       3            3       8.823529
# 4                       1            2       5.882353
# 5                      10            1       2.941176
# 6                      11            1       2.941176
# 7                     113            1       2.941176
# 8                     128            1       2.941176
# 9                     134            1       2.941176
# 10                    135            1       2.941176
# 11                    161            1       2.941176
# 12                    212            1       2.941176
# 13                    215            1       2.941176

# %% [markdown]
# La tabla anterior indica la cantidad de valores faltantes y el numero de variables que comparten dicho valor junto al porcentaje que representa tales variables respecto a las demas

# %% [markdown]
# #### Resumen de valores faltantes por cada registro

# %%
riskfactors_df.missing.missing_case_summary()
# Out:
#      case  n_missing  pct_missing
# 0       0          6    16.666667
# 1       1          6    16.666667
# 2       2          7    19.444444
# 3       3         12    33.333333
# 4       4          5    13.888889
# ..    ...        ...          ...
# 240   240          6    16.666667
# 241   241          5    13.888889
# 242   242          3     8.333333
# 243   243          2     5.555556
# 244   244          3     8.333333
#
# [245 rows x 3 columns]

# %% [markdown]
# La tabla anterior indica la cantidad de valores faltantes por registro del dataframe

# %% [markdown]
# #### Tabla de valores faltantes sobre los registros

# %%
riskfactors_df.missing.missing_case_table()
# Out:
#     n_missing_in_case  n_cases   pct_case
# 0                   4       49  20.000000
# 1                   5       45  18.367347
# 2                   7       39  15.918367
# 3                   6       36  14.693878
# 4                   2       31  12.653061
# 5                   3       30  12.244898
# 6                   1        4   1.632653
# 7                   8        3   1.224490
# 8                  12        3   1.224490
# 9                  15        2   0.816327
# 10                  9        1   0.408163
# 11                 10        1   0.408163
# 12                 11        1   0.408163

# %% [markdown]
# La tabla anterior indica la cantidad de valores faltante y el numero de registros que contienen dicha cantidad

# %% [markdown]
# #### Intervalos de valores faltantes

# %%
riskfactors_df.missing.missing_variable_span(variable='weight_lbs', span_every=50)
# Out:
#    span_counter  n_missing  n_complete  pct_missing  pct_complete
# 0             0          1          49     2.000000     98.000000
# 1             1          5          45    10.000000     90.000000
# 2             2          1          49     2.000000     98.000000
# 3             3          1          49     2.000000     98.000000
# 4             4          2          43     4.444444     95.555556

# %% [markdown]
# La tabla anterior indica el numero de valores faltantes por cada 50 registros para la variable weight_lbs. Muestra el resumen de datos faltantes, datos completos, % de datos faltantes y % de datos completos por bloques de registros

# %% [markdown]
# #### Intervalos consecutivos de valores faltantes y completos

# %%
riskfactors_df.missing.missing_variable_run(variable='weight_lbs')
# Out:
#     run_length     is_na
# 0           14  complete
# 1            1   missing
# 2           45  complete
# 3            1   missing
# 4            5  complete
# 5            1   missing
# 6           12  complete
# 7            1   missing
# 8           10  complete
# 9            2   missing
# 10          40  complete
# 11           1   missing
# 12          53  complete
# 13           1   missing
# 14          14  complete
# 15           1   missing
# 16          31  complete
# 17           1   missing
# 18          11  complete

# %% [markdown]
# La tabla anterior muestra el numero de registros consecutivos que estan completos seguido del numero de registros con valores faltantes. Esta funciones muy util cuando se trabaja con una serie de tiempo

# %% [markdown]
# ## Visualizacion de valores faltantes

# %% [markdown]
# #### Configuracion General de las Graficas

# %%
# %matplotlib inline

# tamaño de los graficos
sns.set(
    rc={
        'figure.figsize':(8, 8)
    }
)

# estilo de los graficos
sns.set_style('whitegrid')

# %% [markdown]
# #### Visualizacion de valores faltantes para cada variable mediante un grafico de paleta

# %%
riskfactors_df.missing.missing_variable_plot()

# %% [markdown]
#  La grafica muestra que la variable pregnant es la que mayor cantidad de valores faltantes tiene, seguido de las variables smoke_stop y smoke_last

# %% [markdown]
# #### Histograma de la cantidad de observaciones con datos faltantes

# %%
riskfactors_df.missing.missing_case_plot()

# %% [markdown]
# La grafica muestra la cantidad de observaciones y su respectiva cantidad de valores faltantes. Para este caso vemos que existen alrededor de 49 observaciones con 5 valores faltantes y 45 con 6 valores faltantes.

# %% [markdown]
# #### Visualizacion de datos faltantes para un rango especifico de observaciones para una variable especifica

# %%
(
    riskfactors_df
    .missing
    .missing_variable_span_plot(
        variable='weight_lbs', # variable a analizar
        span_every=10, # rango de registros
        rot=0 # rotacion de las etiquetas
    )
)

# %% [markdown]
# La grafica muestra la proporcion de datos faltantes por cada 10 registros de la variable weight_lbs. Observamos que entre los registros que van del 60 al 69 hay un 20% de los datos que son valores faltantes; lo mismo sucede con los registros que van del 90 al 99.

# %% [markdown]
# #### Visualizacion de datos faltantes para todas las variables del DataFrame

# %%
# missigno es una funcion de pandas
missingno.bar(df = riskfactors_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# La grafica representa los datos faltantes con espacio en blanco por lo que podemos confirmar que las variables como pregnant, smoke_stop y smoke_last son las que mayor cantidad de valores faltantes contiene

# %% [markdown]
# #### Visualizacion de datos faltantes para cada variable mediante una Matriz

# %%
# es una funcion de pandas
missingno.matrix(df = riskfactors_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# La matriz muestra las variables donde las zonas blancas son valores faltantes. Podemos observar como la variable pregnant es la que mayor cantidad de valores faltantes tiene. Ademas podemos notar que las variables drink_days y drink_average estan relacionadas debido a que muestran un patron muy similar en sus valores faltantes. La grafica tambien muestra picos al lado derecho los cuales representan observaciones donde hay mayor cantidad de valores faltantes

# %% [markdown]
# #### Visualizacion de apariciones conjuntas de valores faltantes entre las variables mediante un upsetplot

# %%
# para todas las variables
(
    riskfactors_df
    .missing
    .missing_upsetplot(
        variables=None, # None para mostrar todas las variables
        element_size = 30 # size de las visualizaciones
    )
)
# Out:
# {'matrix': <AxesSubplot:>,
#  'shading': <AxesSubplot:>,
#  'totals': <AxesSubplot:>,
#  'intersections': <AxesSubplot:ylabel='Intersection size'>}

# %%
# para un conjunto de variables
(
    riskfactors_df
    .missing
    .missing_upsetplot(
        variables=['pregnant','drink_days', 'drink_average'], # None para mostrar todas las variables
        element_size = 30 # size de las visualizaciones
    )
)
# Out:
# {'matrix': <AxesSubplot:>,
#  'shading': <AxesSubplot:>,
#  'totals': <AxesSubplot:>,
#  'intersections': <AxesSubplot:ylabel='Intersection size'>}

# %% [markdown]
# El grafico nos indica que hay mas de 100 observaciones que comparten valores faltantes para las 3 variables. Mientras que las variables drink comparten menos de 25 observaciones con valores faltantes. La variable pregnant alcanza los casi 100 observaciones cuando las variables drink no tienen valores faltantes.

# %% [markdown]
# ## Tipos de Valores Faltantes

# %% [markdown]
# Para este caso, vamos a trabajar con un nuevo conjunto de datos de pacientes diagnosticados con diabetes

# %%
# Pima Indians Diabetes
diabetes_url = "https://nrvis.com/data/mldata/pima-indians-diabetes.csv"

# %%
# !wget -O ./data/pima-indians-diabetes.csv { diabetes_url } -q
# !linea de comandos, 
# wget-comando para descargar datos 
# ruta para almacenar los datos + nombre, {URL}, 
# -q para que no muestre la descarga

# %%
# asignar los nombres de las variables y convertirlo en un dataframe
diabetes_df = pd.read_csv(
    filepath_or_buffer="./data/pima-indians-diabetes.csv", # or pima_indians_diabetes_url
    sep=",",
    names=[
        "pregnancies",
        "glucose",
        "blood_pressure",
        "skin_thickness",
        "insulin",
        "bmi",
        "diabetes_pedigree_function",
        "age",
        "outcome",
    ]
)

# %%
# dataframe de trabajo
diabetes_df
# Out:
#      pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi  \
# 0              6      148              72              35        0  33.6
# 1              1       85              66              29        0  26.6
# 2              8      183              64               0        0  23.3
# 3              1       89              66              23       94  28.1
# 4              0      137              40              35      168  43.1
# ..           ...      ...             ...             ...      ...   ...
# 763           10      101              76              48      180  32.9
# 764            2      122              70              27        0  36.8
# 765            5      121              72              23      112  26.2
# 766            1      126              60               0        0  30.1
# 767            1       93              70              31        0  30.4
#
#      diabetes_pedigree_function  age  outcome
# 0                         0.627   50        1
# 1                         0.351   31        0
# 2                         0.672   32        1
# 3                         0.167   21        0
# 4                         2.288   33        1
# ..                          ...  ...      ...
# 763                       0.171   63        0
# 764                       0.340   27        0
# 765                       0.245   30        0
# 766                       0.349   47        1
# 767                       0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# #### Visualizacion de valores faltantes de cada variable mediante un grafico de paleta

# %%
diabetes_df.missing.missing_variable_plot()

# %% [markdown]
# Del grafico notamos que aparentemente no hay valores faltantes en el dataframe. Sin embargo, al revisar la tabla del dataframe vemos que los valores faltantes vienen representados por ceros. En este caso lo que se hace es sustituir los ceros por nan para que sean detectados como valores faltantes

# %% [markdown]
# #### Sustitucion de Ceros por NaN

# %%
# sustituimos solo los valores que estan entre las variables 1 y 5 debido a que son las de
# interes
diabetes_df[diabetes_df.columns[1:6]] = diabetes_df[diabetes_df.columns[1:6]].replace(0, np.nan)

# %% [markdown]
# #### Visualizacion de datos faltantes mediante un grafico de paletas

# %%
diabetes_df.missing.missing_variable_plot()

# %%
(
    diabetes_df
    .pipe(missingno.matrix)
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 1. Tipo MCAR

# %% [markdown]
# Estos son datos faltantes ocasionados por herramientas que dejan de funcionar sin ninguna razon aparente. La localizacion de valores faltantes ocurre completamente al azar

# %%
# ordena la variables de la qu mas tiene valores faltantes a la que menos tiene
(
    diabetes_df # dataframe
    .missing.sort_variables_by_missingness() # ordena las variable de mayor a menor cantidad de valores faltantes
    .pipe(missingno.matrix) # muestra el resultado como una matriz
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Del grafico concluimos que en las variables bmi y glucose hay tan pocos valores faltantes que se pueden considerar valores faltantes al azar o de tipo MCAR

# %% [markdown]
# #### 2. Tipo MAR

# %% [markdown]
# Son ocasionados en fechas controladas como por ejemplo cuando se hace mantenimiento a las herramienas. La localizacion de los valores faltantes depende de otros valores observados

# %%
(
    diabetes_df
    .missing.sort_variables_by_missingness()
    .sort_values(by='blood_pressure') # ordena los valores segun una columna
    .pipe(missingno.matrix)
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Para este caso, los valores faltantes de la variable blood_pressure pueden estar relacionados a algunos valores de insulin o de skin_thickness por lo que son de tipo MAR

# %% [markdown]
# #### 3. Tipo MNAR

# %% [markdown]
# Este tipo de datos faltantes proviene de los limites que presentan las herramientas al tratar de hacer seguimiento fuera de su rango de medicion. La localizacion de los valores faltantes depende de los valores faltantes en si mismo

# %%
(
    diabetes_df
    .missing.sort_variables_by_missingness()
    .sort_values(by='insulin') # ordena los valores segun una columna
    .pipe(missingno.matrix)
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Vemos que hay un rango de insulina en la que estan la mayoria de los valores faltantes de las demas variables por lo que concluimos que es de tipo MNAR

# %% [markdown]
# No podemos tener seguridad sobre cual mecanismo incide sobre los datos para generar los valores faltantes, pero a traves de analisis y conocimiento del tema se pueden hacer suposiciones razonables

# %% [markdown]
# ## Matriz de Sombra

# %% [markdown]
# Permiten establecer relaciones entre las variables que tienen todas sus observaciones y la ausencia o presencia de otras variables de forma que se pueda comparar estadisticos o visualizarlos de manera efectiva.
#
# Para este caso, vamos a crear una matriz de sombra con los datos del dataframe riskfactor

# %% [markdown]
# #### Construccion de la matriz de sombra manualmente

# %%
(
    riskfactors_df
    .isna()                     # crea una matriz de booleanos con los datos del df
    .replace({                  # reemplaza los valores booleanos por valores informativos
        False:'Not missing',
        True: 'Missing'
    })
    .add_suffix('_NA')          # Agrega un sufijo sobre cada variable
    .pipe(
        lambda shadow_matrix: pd.concat( # concatena los valores de la matriz de sombra a la derecha del df
            [riskfactors_df, shadow_matrix],
            axis='columns'
        )
    )
)
# Out:
#     state     sex  age weight_lbs height_inch    bmi   marital pregnant  \
# 0      26  Female   49        190          64  32.68   Married      NaN
# 1      40  Female   48        170          68  25.90  Divorced      NaN
# 2      72  Female   55        163          64  28.04   Married      NaN
# 3      42    Male   42        230          74  29.59   Married      NaN
# 4      32  Female   66        135          62  24.74   Widowed      NaN
# ..    ...     ...  ...        ...         ...    ...       ...      ...
# 240    10  Female   79        144          63  25.56   Widowed      NaN
# 241    46    Male   45        170          74  21.87  Divorced      NaN
# 242    15    Male   62        175          71  24.46  Divorced      NaN
# 243    34  Female   62        138          64  23.74   Married      NaN
# 244    18    Male    9        200          70  28.76   Married      NaN
#
#      children education  ... smoke_100_NA smoke_days_NA smoke_stop_NA  \
# 0           0         6  ...  Not missing       Missing       Missing
# 1           0         5  ...  Not missing       Missing       Missing
# 2           0         4  ...  Not missing       Missing       Missing
# 3           1         6  ...  Not missing       Missing       Missing
# 4           0         5  ...  Not missing   Not missing   Not missing
# ..        ...       ...  ...          ...           ...           ...
# 240         0         4  ...  Not missing       Missing       Missing
# 241         2         4  ...  Not missing       Missing       Missing
# 242         0         6  ...  Not missing   Not missing       Missing
# 243         0         4  ...  Not missing   Not missing   Not missing
# 244         0         4  ...  Not missing   Not missing       Missing
#
#     smoke_last_NA diet_fruit_NA  diet_salad_NA  diet_potato_NA diet_carrot_NA  \
# 0         Missing   Not missing    Not missing     Not missing    Not missing
# 1         Missing   Not missing    Not missing     Not missing    Not missing
# 2         Missing   Not missing    Not missing     Not missing    Not missing
# 3         Missing       Missing        Missing         Missing        Missing
# 4         Missing   Not missing    Not missing     Not missing    Not missing
# ..            ...           ...            ...             ...            ...
# 240       Missing   Not missing    Not missing     Not missing    Not missing
# 241       Missing   Not missing    Not missing     Not missing    Not missing
# 242   Not missing   Not missing    Not missing     Not missing    Not missing
# 243       Missing   Not missing    Not missing     Not missing    Not missing
# 244   Not missing   Not missing    Not missing     Not missing    Not missing
#
#     diet_vegetable_NA diet_juice_NA
# 0         Not missing   Not missing
# 1         Not missing   Not missing
# 2         Not missing   Not missing
# 3             Missing       Missing
# 4         Not missing   Not missing
# ..                ...           ...
# 240       Not missing   Not missing
# 241       Not missing   Not missing
# 242       Not missing   Not missing
# 243       Not missing   Not missing
# 244       Not missing   Not missing
#
# [245 rows x 68 columns]

# %% [markdown]
# #### Construccion de la Matriz de sombra mediante la funcion bind_shadow_matrix

# %%
(
    riskfactors_df
    .missing
    .bind_shadow_matrix(only_missing = True)
)
# Out:
#     state     sex  age weight_lbs height_inch    bmi   marital pregnant  \
# 0      26  Female   49        190          64  32.68   Married      NaN
# 1      40  Female   48        170          68  25.90  Divorced      NaN
# 2      72  Female   55        163          64  28.04   Married      NaN
# 3      42    Male   42        230          74  29.59   Married      NaN
# 4      32  Female   66        135          62  24.74   Widowed      NaN
# ..    ...     ...  ...        ...         ...    ...       ...      ...
# 240    10  Female   79        144          63  25.56   Widowed      NaN
# 241    46    Male   45        170          74  21.87  Divorced      NaN
# 242    15    Male   62        175          71  24.46  Divorced      NaN
# 243    34  Female   62        138          64  23.74   Married      NaN
# 244    18    Male    9        200          70  28.76   Married      NaN
#
#      children education  ... smoke_100_NA smoke_days_NA smoke_stop_NA  \
# 0           0         6  ...  Not Missing       Missing       Missing
# 1           0         5  ...  Not Missing       Missing       Missing
# 2           0         4  ...  Not Missing       Missing       Missing
# 3           1         6  ...  Not Missing       Missing       Missing
# 4           0         5  ...  Not Missing   Not Missing   Not Missing
# ..        ...       ...  ...          ...           ...           ...
# 240         0         4  ...  Not Missing       Missing       Missing
# 241         2         4  ...  Not Missing       Missing       Missing
# 242         0         6  ...  Not Missing   Not Missing       Missing
# 243         0         4  ...  Not Missing   Not Missing   Not Missing
# 244         0         4  ...  Not Missing   Not Missing       Missing
#
#     smoke_last_NA diet_fruit_NA  diet_salad_NA  diet_potato_NA diet_carrot_NA  \
# 0         Missing   Not Missing    Not Missing     Not Missing    Not Missing
# 1         Missing   Not Missing    Not Missing     Not Missing    Not Missing
# 2         Missing   Not Missing    Not Missing     Not Missing    Not Missing
# 3         Missing       Missing        Missing         Missing        Missing
# 4         Missing   Not Missing    Not Missing     Not Missing    Not Missing
# ..            ...           ...            ...             ...            ...
# 240       Missing   Not Missing    Not Missing     Not Missing    Not Missing
# 241       Missing   Not Missing    Not Missing     Not Missing    Not Missing
# 242   Not Missing   Not Missing    Not Missing     Not Missing    Not Missing
# 243       Missing   Not Missing    Not Missing     Not Missing    Not Missing
# 244   Not Missing   Not Missing    Not Missing     Not Missing    Not Missing
#
#     diet_vegetable_NA diet_juice_NA
# 0         Not Missing   Not Missing
# 1         Not Missing   Not Missing
# 2         Not Missing   Not Missing
# 3             Missing       Missing
# 4         Not Missing   Not Missing
# ..                ...           ...
# 240       Not Missing   Not Missing
# 241       Not Missing   Not Missing
# 242       Not Missing   Not Missing
# 243       Not Missing   Not Missing
# 244       Not Missing   Not Missing
#
# [245 rows x 58 columns]

# %% [markdown]
# Esta funcion aplica solo para las columnas que contienen valores faltantes siempre que el parametro only_missing sea True

# %% [markdown]
# #### Exploracion de estadisticos utilizando las nuevas columnas de la matriz de sombra

# %%
# weight_lbs_NA vs age

print('Valores faltantes en la variable Peso segun la Edad ')
(
    riskfactors_df
    .missing.bind_shadow_matrix(only_missing=True) # crea la matriz de sombra
    .groupby(['weight_lbs_NA'])                    # agrupar por la ausencia de la variable Peso
    ['age']                                        # variable edad como referencia
    .describe()
    .reset_index()
)
# Out:
# Valores faltantes en la variable Peso segun la Edad
#   weight_lbs_NA  count       mean        std   min    25%   50%   75%   max
# 0       Missing   10.0  60.100000  13.706851  37.0  52.25  62.5  65.0  82.0
# 1   Not Missing  235.0  58.021277  17.662904   7.0  47.50  59.0  70.0  97.0

# %% [markdown]
# Para los valores faltantes de Peso segun la edad vemos que donde hay datos, la media de edad es de 58 y la edad maxima es de 97. Mientras que para los valores faltantes la media de edad es de 60 y la edad maxima es de 82. La cercania entre ambos resultados indican que los valores faltantes en weight_lbs no estan relacionados con age

# %%
# pregnant_NA vs age

print('Valores faltantes en la variable Pregnant segun Age ')
(
    riskfactors_df
    .missing.bind_shadow_matrix(only_missing=True) # crea la matriz de sombra
    .groupby(['pregnant_NA'])                      # agrupar por la ausencia de la variable pregnant
    ['age']                                        # variable edad como referencia
    .describe()
    .reset_index()
)
# Out:
# Valores faltantes en la variable Pregnant segun Age
#    pregnant_NA  count       mean        std  min   25%   50%   75%   max
# 0      Missing  215.0  61.590698  15.430577  9.0  52.0  62.0  71.5  97.0
# 1  Not Missing   30.0  33.133333   9.212934  7.0  29.5  34.0  40.0  44.0

# %% [markdown]
# Para los valores faltantes de pregnant en funcion de la edad vemos que donde hay datos la edad media es de 33 y la edad maxima es de 44 que es el año donde las mujeres alcanzan su maximo de edad reproductiva. Mientras que para los valores faltantes la edad media es de 61 y el maximo de edad es de 97, etapa donde las mujeres ya pasaron su edad reproductiva. Por tanto concluimos que los valores faltantes en pregnant estan relacionados con la variable age.

# %%
# bmi_NA vs weight_lbs

print('Valores faltantes o no en la variable bmi_NA segun weight_lbs')
(
    riskfactors_df
    .missing.bind_shadow_matrix(only_missing=True) # crea la matriz de sombra
    .groupby(['bmi_NA'])                           # agrupar por la ausencia de la variable pregnant
    ['age']                                 # variable edad como referencia
    .describe()
    .reset_index()
)
# Out:
# Valores faltantes o no en la variable bmi_NA segun weight_lbs
#         bmi_NA  count       mean        std   min    25%   50%    75%   max
# 0      Missing   11.0  62.363636  15.015144  37.0  54.50  63.0  70.00  85.0
# 1  Not Missing  234.0  57.905983  17.611927   7.0  47.25  59.0  69.75  97.0

# %% [markdown]
# La cercania en los resultados de valores faltantes con valores completos indican que los valores faltantes de bmi no estan relacionados con la variable age.
#
# La similitud en los resultados tanto de weight como de bmi sugieren que ambos son valores de tipo MAR debido a que uno depende de las observaciones del otro.

# %% [markdown]
# ## Visualizacion de Valores Faltantes en una variable

# %% [markdown]
# Permite detectar si esta ocurriendo un sesgo en la presencia o ausencia de valores faltantes ocasionados por otra variable. Para este caso, se contrasta una variable que tiene todos sus valores completos con otra variable que contiene valores faltantes

# %% [markdown]
# #### Visualizacion de valores faltantes mediante un Diagrama de Caja

# %%
# Comparando los valores faltantes de la variable Peso con los valores de Edad

(
    riskfactors_df
    .missing
    .bind_shadow_matrix(only_missing=True) # crea la matriz de sombra
    .pipe(
        lambda df: (
            sns.boxenplot(                 # diagrama de caja
                data=df,                   # dataframe donde se encuentran las variables
                x='weight_lbs_NA',         # variable con los datos faltantes
                y='age'                    # variable de comparacion
            )
        )   
    )
)
# Out:
# <AxesSubplot:xlabel='weight_lbs_NA', ylabel='age'>

# %% [markdown]
# Del diagrama notamos que los valores faltantes de Peso estan por encima de la edad de 60 mientras que los valores de Peso estan por debajo de 60

# %% [markdown]
# #### Visualizacion de valores faltantes mediante una Funcion de Densidad

# %%
# Comparando los valores faltantes de la variable Peso con los valores de Edad

(
    riskfactors_df
    .missing.bind_shadow_matrix(only_missing=True)
    .pipe(
        lambda df:(
            sns.displot(
                data=df,
                x='age',
                hue='weight_lbs_NA',
                kind='kde'
            )
        )
    )
)

# %% [markdown]
# La grafica de densidad tambien nos muestra como los valores faltantes del Peso estan sesgado levemente a la derecha. Cabe resltar que no es la mejor visualizacion debido a la diferencia en las densidades

# %% [markdown]
# #### Visualizacion de valores faltantes mediante Histogramas

# %%
# Comparando los valores faltantes de la variable Peso con los valores de Edad

(
    riskfactors_df
    .missing.bind_shadow_matrix(only_missing=True)
    .pipe(
        lambda df:(
            sns.displot(
                data=df,
                x='age',
                col='weight_lbs_NA'
            )
        )
    )
)

# %% [markdown]
# Este tipo de graficos son muy dificiles de comparar debido a que hay mas datos completos que faltantes

# %% [markdown]
# #### Visualizacion de valores faltantes mediante Histogramas Independientes

# %%
# Eje de las y independientes para cada grafico
(
    riskfactors_df
    .missing.bind_shadow_matrix(only_missing=True)
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x = 'age', #variable de distribucion
                col = 'weight_lbs_NA',  #variable de comparacion
                facet_kws={
                    'sharey': False
                }               
            )
        )
    )
)

# %% [markdown]
# Al dejar independiente el eje Y de cada histograma la visualizacion mejora muchisimo, sin embargo, hay que tener en cuenta que estan en escalas diferentes

# %% [markdown]
# #### Visualizacion de datos faltantes para dos variables mediante una grilla de Histogramas

# %%
# comparando los valores faltantes del Peso y estado Marital con los valores de Edad

(
    riskfactors_df
    .missing.bind_shadow_matrix(only_missing=True)
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x = 'age', #variable de distribucion
                col = 'marital_NA',  #variable de comparacion
                row = 'weight_lbs_NA'               
            )
        )
    )
)

# %% [markdown]
# En la grilla notamos que no existe edades para los valores faltantes de Peso y estado Marital. Esto indica que son valores faltantes de tipo MAR en relacion con la edad, es decir, para poder obtener el Peso y estado Marital debe de saberse primero la edad de la persona.
#
# Tambien vemos que existe un mayor numero de datos de Peso y estado Marital para la edad de 60

# %% [markdown]
# ## Visualizacion de valores faltantes en dos variables

# %% [markdown]
# Permiten visualizar y compara dos variables cuando ambas le faltan valores. Un grafico muy util para ello, son los Scatterplot.
#
# Vamos a crear una funcion que agregue valores aleatorios a las variables con valores faltantes

# %%
'''
Funcion que agrega valores aleatorios a las variables con valores faltantes
para visualizarlos en un eje
'''

def column_fill_with_dummies(
    column: pd.Series,
    proportion_below: float=0.10, # proporcion de los datos en la grafica
    jitter: float=0.075,          # parametro que evita el asolapamiento de los puntos de la grafica
    seed: int=42                  # semilla para la aleatoriedad
) -> pd.Series:                   # la funcion retorna una Serie

    # copiar las columnas del DataFrame
    column = column.copy(deep=True)

    # extraer los valores de las variables 
    missing_mask = column.isna()                # matriz de booleanos
    number_missing_values = missing_mask.sum()  # conteo de valores faltantes
    column_range = column.max() - column.min()  # rango de las variables

    # Datos de turno
    column_shift = column.min() - column.min()*proportion_below

    # Ruido alrededor de los puntos
    np.random.seed(seed)
    column_jitter = (np.random.rand(number_missing_values) - 2) * column_range * jitter

    # guarda los nuevos datos aleatorios
    column[missing_mask] = column_shift + column_jitter

    return column

# %% [markdown]
# #### Scatterplot para dos variables con valores faltantes

# %%
# analisis para las variables numericas Peso y Altura
(
    riskfactors_df
    .select_dtypes(
        exclude='category'  # excluye las variables categoricas
    )
    .pipe(                  # selecciona solo columnas que tengan valores faltantes
        lambda df: df[df.columns[df.isna().any()]]
    )                       # matriz de sombra con valor True para valores faltantes y False para valores completos
    .missing.bind_shadow_matrix(true_string = True, false_string = False)
    .apply(                 # funcion que rellena los valores faltantes con column_fill_with_dummies
        lambda column: column if '_NA' in column.name else column_fill_with_dummies(column, proportion_below=0.05, jitter=0.075)
    )                       
    .assign(                # nueva columna con las variables a graficar (en formato booleano)
        nullity = lambda df: df.weight_lbs_NA | df.height_inch_NA
    )
    .pipe(                  # funcion para graficar el scatterplot
        lambda df: (
            sns.scatterplot(
                data = df,
                x='weight_lbs',
                y='height_inch',
                hue='nullity'
            )
        )
    )
)
# Out:
# <AxesSubplot:xlabel='weight_lbs', ylabel='height_inch'>

# %% [markdown]
# Los puntos azules de la grafica representan los valores completos, existen observaciones para ambas variables. Los puntos naranja indican que existe observacion para una variable y no para la otra. Para el caso de la altura vemos que existe una mayor cantidad de valores que tienen altura pero no el peso y que se agrupan en un rango que de 60 a 70 pulgadas. Para la variable Peso, vemos que solo tiene un valor que no contiene la Altura.

# %% [markdown]
# ## Correlacion de Nulidad

# %% [markdown]
# Nos ayuda a encontrar relaciones entre las variables en funcion de su nulidad. Existen diferentes maneras de visualizar este tipo de correlacion entre las que tenemos: Heatmaps y dendogramas

# %% [markdown]
# #### Heatmaps de las variables contenidas en riskfactors

# %%
missingno.heatmap(df=riskfactors_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Los valores grises indican que no hay correlacion ni positiva ni negativa entre los valores faltantes de las variables
#
# - Los valores azules indican una correlacion positiva, es decir, la presencia de un valor faltante en una variable esta correlacionado con un valor faltante en la otra. Variables diet.
#
# - Los valores rojos indican una correlacion negativa, es decirs, mientras en una de las variables hay un valor faltante en la otra hay un valor completo. Variables smoke_last y smoke_stop.
#
# - El simbolo <1 indica que esta cerca del 100% de correlacion.

# %% [markdown]
# #### Dendograma de las variables contenidas en riskfactors

# %%
missingno.dendrogram(df=riskfactors_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Las variables agrupadas cerca del nivel base indican que la presencia de valores faltantes estan muy relacionadas entre si.
#
# - Mientras mas separado esten las variables en el diagrama es menos probables que sus valores faltantes esten correlacionados.

# %% [markdown]
# ## Eliminacion de Valores Faltantes

# %% [markdown]
# Existen dos metodos para el tratamientos de valores faltantes: Eliminacion e Imputacion.
#
# - En la eliminacion de valores faltantes se asume que los valores estan perdidos completamente al azar (MCAR). En cualquier otro caso, realizar una eliminacion podra ocasionar sesgos en los analisis y modelos subsecuentes.
#
# - La imputacion consiste en añadir valores en los datos faltantes para mantener el registro en el datasets.

# %% [markdown]
# ### Proceso de eliminacion de datos faltantes

# %%
# observar el numero de registros y variables que contiene el dataset
riskfactors_df.shape
# Out:
# (245, 34)

# %% [markdown]
# #### Eliminacion por pares (Pairwise deletion)

# %%
# viene ya incorporado a Pandas. Ignora los registros con datos faltantes

# calculo de la media de la variable peso
(
    riskfactors_df
    .weight_lbs
    .mean()
)
# Out:
# 174.26808510638298

# %%
# cantidad de registros de Peso vs cantidad de datos completos de Peso
riskfactors_df.weight_lbs.size, riskfactors_df.weight_lbs.count()
# Out:
# (245, 235)

# %% [markdown]
# Esto indica que hay 245 registros de los cuales 235 estan completos para la variable Peso

# %%
# media de la variable Peso considerando los valores faltantes
riskfactors_df.weight_lbs.mean(skipna=False)
# Out:
# nan

# %% [markdown]
# #### Eliminacion por caso completo (Listwise deletion) en funcion de una variable

# %%
# elimina el registro completo donde aparezca un valor faltante en una variable seleccionada

(
    riskfactors_df
    .dropna(
        subset=['weight_lbs'], # variable seleccionada
        how='any'              # any para cualquier valor faltante que aparezca
    )
).shape
# Out:
# (235, 34)

# %% [markdown]
# Podemos observar que fueron eliminados 10 casos completos los cuales tenian valores faltantes en la variable Peso

# %% [markdown]
# #### Eliminacion por caso completo (Listwise deletion) en funcion de dos variables

# %%
# elimina el registro completo donde aparezca un valor faltante en las variables seleccionada

(
    riskfactors_df
    .dropna(
        subset=['weight_lbs', 'height_inch'], # variables seleccionadas
        how='any'              # all para cualquier valor faltante que aparezca en cualquiera de las dos variables
    )
).shape
# Out:
# (234, 34)

# %% [markdown]
# Como se observa, fueron eliminados 11 registros donde se encuentra valores faltantes en cualquiera de las dos variables

# %% [markdown]
# #### Eliminacion por caso completo donde ambas variables contengan valores faltantes

# %%
# elimina los registros donde hayan valores faltantes en ambas variables simultaneamente

(
    riskfactors_df
    .dropna(
        subset=['weight_lbs', 'height_inch'],
        how='all'
    )
).shape
# Out:
# (244, 34)

# %% [markdown]
# Del resultado anterior, deducimos que solo hay un registro donde ambas variables poseen valores faltantes

# %% [markdown]
# ### Visualizacion de los datos tras la Eliminacion de valores faltantes

# %%
# Con any

(
    riskfactors_df
    .dropna(
        subset=['weight_lbs', 'height_inch'], # variables seleccionadas
        how='any'                             # any para cualquier registro que contenga valores faltantes en cualquiera de las variables
    )
    .select_columns(['weight_lbs', 'height_inch'])
    .pipe(missingno.matrix)                   #grafica de matriz para ambas variables
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observamos que los datos de ambas variables quedan limpios de datos faltantes

# %%
# con all

(
    riskfactors_df
    .dropna(
        subset=['weight_lbs', 'height_inch'], # variables seleccionadas
        how='all'                             # any para cualquier registro que contenga valores faltantes en cualquiera de las variables
    )
    .select_columns(['weight_lbs', 'height_inch'])
    .pipe(missingno.matrix)                   #grafica de matriz para ambas variables
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Es este caso, aunque quedan registros en ambas variables con valores faltantes, se han eliminado aquellos con valores faltantes en ambas variables

# %% [markdown]
# ## Imputacion Basica de los Datos

# %% [markdown]
# Consiste en reemplazar los valores faltantes por algun valor, bien sea estadistico, algun valor por contexto o valores obtenidos mediante un modelo de Machine Learning

# %% [markdown]
# ### Imputacion con base en el contexto

# %% [markdown]
# implica conocer la estructura de los datos por lo que podemos completar las entradas vacias

# %% [markdown]
# ### Imputacion de un unico valor

# %% [markdown]
# Se da cuando el contexto no ayuda a completar un valor faltante y por tanto requieres imputar un unico valor con algun estadistico. Para este caso, utilizamos las variables Peso, Altura y bmi para aplicar el valor promedio a cada valor faltante. Ademas creamos la matriz de sombras de las tres variables para luego crear una grafica representativa

# %%
# Matriz de sombra para las variables Peso, Altura y bmi
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    )
)
# Out:
#      weight_lbs  height_inch    bmi  weight_lbs_NA  height_inch_NA  bmi_NA
# 0         190.0         64.0  32.68          False           False   False
# 1         170.0         68.0  25.90          False           False   False
# 2         163.0         64.0  28.04          False           False   False
# 3         230.0         74.0  29.59          False           False   False
# 4         135.0         62.0  24.74          False           False   False
# ..          ...          ...    ...            ...             ...     ...
# 240       144.0         63.0  25.56          False           False   False
# 241       170.0         74.0  21.87          False           False   False
# 242       175.0         71.0  24.46          False           False   False
# 243       138.0         64.0  23.74          False           False   False
# 244       200.0         70.0  28.76          False           False   False
#
# [245 rows x 6 columns]

# %% [markdown]
# #### Visualizacion de los datos faltantes imputados

# %%
# Para la variable Peso
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    ).pipe(
        lambda df:(                                         # seccion del Grafico
            sns.displot(
                data= df,
                x='weight_lbs',
                hue='weight_lbs_NA'  # el color se muestra como valor faltante
            )
        )    
    )   
)

# %% [markdown]
# Vemos que los valores imputados de Peso, de color naranja, tienen valores que estan en la media de los datos

# %%
# Para la variable Altura
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    ).pipe(
        lambda df:(                                         # Seccion del Grafico
            sns.displot(
                data= df,
                x='height_inch',
                hue='height_inch_NA'
            )
        )    
    )   
)

# %% [markdown]
# En esta grafica tambien se observa que los valores imputados de Altura tienen valores que se acerca a la media de los datos

# %% [markdown]
# #### Imputacion de Valores sobre Multiples Variables

# %%
# Imputacion simultanea para las variables Peso, Altura y bmi
# Creamos una nueva columna con True para registros donde hayan valores faltantes
# en peso o altura
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    )  
    .assign(                                                # nueva columna
        imputed=lambda df: df.weight_lbs_NA | df.height_inch_NA
    )   
)
# Out:
#      weight_lbs  height_inch    bmi  weight_lbs_NA  height_inch_NA  bmi_NA  \
# 0         190.0         64.0  32.68          False           False   False
# 1         170.0         68.0  25.90          False           False   False
# 2         163.0         64.0  28.04          False           False   False
# 3         230.0         74.0  29.59          False           False   False
# 4         135.0         62.0  24.74          False           False   False
# ..          ...          ...    ...            ...             ...     ...
# 240       144.0         63.0  25.56          False           False   False
# 241       170.0         74.0  21.87          False           False   False
# 242       175.0         71.0  24.46          False           False   False
# 243       138.0         64.0  23.74          False           False   False
# 244       200.0         70.0  28.76          False           False   False
#
#      imputed
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
#
# [245 rows x 7 columns]

# %%
# Imputacion simultanea para las variables Peso, Altura y bmi
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    )  
    .assign(                                                # nueva columna
        imputed=lambda df: df.weight_lbs_NA | df.height_inch_NA
    )  
    .pipe(                                                  # seccion de la grafica
        lambda df: (
            sns.scatterplot(
                data=df,
                x='weight_lbs',
                y='height_inch',
                hue='imputed'
            )
        )
    )
)
# Out:
# <AxesSubplot:xlabel='weight_lbs', ylabel='height_inch'>

# %% [markdown]
# Los valores naranjas para este caso, ya no se encuentran fuera de la grafica sino que adquieren un valor promedio en ambas variables. Tales valores son valores imputados y son considerados dentro del conjunto total de datos.
#
# - Si los valores imputados rompen la estructura de los datos implica que la imputacion sesga los datos y podria alterar los resultados. En este caso no altera la estructura de los datos

# %% [markdown]
# #### Visualizacion Multiple de Imputaciones

# %% [markdown]
# Visualiza la imputacion de multiples variables como sigue:

# %%
# Histogramas para varias variables 
# matriz de sombra para las variables peso, altura y bmi
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    )
)
# Out:
#      weight_lbs  height_inch    bmi  weight_lbs_NA  height_inch_NA  bmi_NA
# 0         190.0         64.0  32.68          False           False   False
# 1         170.0         68.0  25.90          False           False   False
# 2         163.0         64.0  28.04          False           False   False
# 3         230.0         74.0  29.59          False           False   False
# 4         135.0         62.0  24.74          False           False   False
# ..          ...          ...    ...            ...             ...     ...
# 240       144.0         63.0  25.56          False           False   False
# 241       170.0         74.0  21.87          False           False   False
# 242       175.0         71.0  24.46          False           False   False
# 243       138.0         64.0  23.74          False           False   False
# 244       200.0         70.0  28.76          False           False   False
#
# [245 rows x 6 columns]

# %%
# Histogramas para varias variables 
# pivotear la columna colocando las NA como primeras columnas
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    )
    .pivot_longer(                                          # pivotear la matriz de sombra hacia los valores NA
        index='*_NA'                                        # colocar de primero las columnas con sufijo NA
    )
)
# Out:
#      weight_lbs_NA  height_inch_NA  bmi_NA    variable   value
# 0            False           False   False  weight_lbs  190.00
# 1            False           False   False  weight_lbs  170.00
# 2            False           False   False  weight_lbs  163.00
# 3            False           False   False  weight_lbs  230.00
# 4            False           False   False  weight_lbs  135.00
# ..             ...             ...     ...         ...     ...
# 730          False           False   False         bmi   25.56
# 731          False           False   False         bmi   21.87
# 732          False           False   False         bmi   24.46
# 733          False           False   False         bmi   23.74
# 734          False           False   False         bmi   28.76
#
# [735 rows x 5 columns]

# %%
# Histogramas para varias variables 
# Colocar las columnas variable y value como index
# crear nueva columna con true para los registros donde los valores de variables esten en variable_NA
# es decir, que exista el valor
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    )
    .pivot_longer(                                          # pivotear la matriz de sombra hacia los valores NA
        index='*_NA'                                        
    )
    .pivot_longer(
        index=['variable', 'value'],
        names_to='variable_NA',
        values_to='value_NA'
    )
    .assign(                                                # nueva columna 
        valid=lambda df: df.apply(axis='columns', func = lambda column: column.variable in column.variable_NA)
    )
    .query('valid')
)
# Out:
#         variable   value    variable_NA  value_NA  valid
# 0     weight_lbs  190.00  weight_lbs_NA     False   True
# 1     weight_lbs  170.00  weight_lbs_NA     False   True
# 2     weight_lbs  163.00  weight_lbs_NA     False   True
# 3     weight_lbs  230.00  weight_lbs_NA     False   True
# 4     weight_lbs  135.00  weight_lbs_NA     False   True
# ...          ...     ...            ...       ...    ...
# 2200         bmi   25.56         bmi_NA     False   True
# 2201         bmi   21.87         bmi_NA     False   True
# 2202         bmi   24.46         bmi_NA     False   True
# 2203         bmi   23.74         bmi_NA     False   True
# 2204         bmi   28.76         bmi_NA     False   True
#
# [735 rows x 5 columns]

# %%
# Histogramas para varias variables 
# Visualizacion de la imputacion para varias variables
(
    riskfactors_df                                          # dataframe
    .select_columns('weight_lbs', 'height_inch', 'bmi')     # variables seleccionadas
    .missing.bind_shadow_matrix(true_string=True, false_string=False) # creacion de la matriz de sombra
    .apply(
        axis = 'rows',
        func = lambda column: column.fillna(column.mean() if '_NA' not in column.name else column)
    )
    .pivot_longer(                                          # pivotear la matriz de sombra hacia los valores NA
        index='*_NA'                                        
    )
    .pivot_longer(
        index=['variable', 'value'],
        names_to='variable_NA',
        values_to='value_NA'
    )
    .assign(                                                # nueva columna 
        valid=lambda df: df.apply(axis='columns', func = lambda column: column.variable in column.variable_NA)
    )
    .query('valid')
    .pipe(
        lambda df:(
            sns.displot(
                data=df,
                x='value',
                hue='value_NA',
                col='variable',
                common_bins=False,
                facet_kws={         # permite independizar el eje Y de las graficas
                    'sharex':False,
                    'sharey':False
                }
            )
        )
    )
)
