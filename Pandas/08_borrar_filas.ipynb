# %% [markdown]
# ## Borrar filas de un archivos CSV

# %%
#librerias
import pandas as pd

# %%
# cargar datos
df = pd.read_csv('./data/canciones.csv')

# %%
# resumen del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     int64
#  1   Song        32 non-null     object
#  2   Peak        32 non-null     int64
#  3   Weeks       32 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.1+ KB

# %%
df.head()
# Out:
#    Unnamed: 0                Song  Peak  Weeks
# 0          76    Paperback Writer     1     16
# 1         117        Lady Madonna     1      9
# 2         118            Hey Jude     1     27
# 3          22   Can't Buy Me Love     1     17
# 4          29  A Hard Day's Night     1     14

# %% [markdown]
# ### Eliminar la ultima fila del dataset

# %%
# numero de filas
filas = len(df.index)
filas
# Out:
# 32

# %%
# eliminar ultima fila
df.drop(df.index[[filas - 1]], inplace=True)
filas = len(df.index)

# %%
filas
# Out:
# 31

# %% [markdown]
# ### Eliminar fila por indice

# %%
# eliminar la fila 1 y 2

# lista de indices a eliminar       axis = 0 para filas. axis = 1 para columnas
df.drop([1,2], axis=0)
# Out:
#     Unnamed: 0                                   Song  Peak  Weeks
# 0           76                       Paperback Writer     1     16
# 3           22                      Can't Buy Me Love     1     17
# 4           29                     A Hard Day's Night     1     14
# 5           48                         Ticket To Ride     1     14
# 6           56                                  Help!     1     17
# 7          109                   All You Need Is Love     1     16
# 8          173            The Ballad Of John And Yoko     1     13
# 9           85                          Eleanor Rigby     1     14
# 10          87                       Yellow Submarine     1     14
# 11          20               I Want To Hold Your Hand     1     24
# 12          45                            I Feel Fine     1     15
# 13          60                            Day Tripper     1     12
# 14          61                     We Can Work It Out     1     12
# ...

# %% [markdown]
# ### Eliminar filas que cumplen una condicion con drop

# %%
# creamos una lista con los indices de las filas que cumple una condicion
weeks_mayor_16 = df[df['Weeks'] > 16].index
weeks_mayor_16
# Out:
# Int64Index([2, 3, 6, 11, 15, 19, 24, 27, 29], dtype='int64')

# %%
# pasamos la lista como argumento de drop
df.drop(weeks_mayor_16, inplace=True)

# %%
df
# Out:
#     Unnamed: 0                                   Song  Peak  Weeks
# 0           76                       Paperback Writer     1     16
# 1          117                           Lady Madonna     1      9
# 4           29                     A Hard Day's Night     1     14
# 5           48                         Ticket To Ride     1     14
# 7          109                   All You Need Is Love     1     16
# 8          173            The Ballad Of John And Yoko     1     13
# 9           85                          Eleanor Rigby     1     14
# 10          87                       Yellow Submarine     1     14
# 12          45                            I Feel Fine     1     15
# 13          60                            Day Tripper     1     12
# 14          61                     We Can Work It Out     1     12
# 16         155                               Get Back     1      6
# 17           8                         From Me To You     1      7
# ...
