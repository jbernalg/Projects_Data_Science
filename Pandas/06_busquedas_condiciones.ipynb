# %% [markdown]
# ## Busquedas de Datos con Condiciones

# %%
#librerias
import pandas as pd

# %%
# cargar datos
datos = pd.read_csv('./data/ATP.csv')
# Out:
# /tmp/ipykernel_2256/3353967361.py:2: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos = pd.read_csv('./data/ATP.csv')

# %%
# fijar indice
datos.set_index('Location', inplace=True)

# %% [markdown]
# ### Buscar Registros que cumplan con una condicion

# %%
# resultados de canchas al aire libre
#               condicion               columna a mostrar
datos.loc[datos['Court'] == 'Outdoor', ['Surface']]
# Out:
#          Surface
# Location
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# ...          ...
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
#
# [38350 rows x 1 columns]

# %%
#               condicion               columnas a mostrar
datos.loc[datos['Court'] == 'Outdoor', ['Surface', 'Winner']]
# Out:
#          Surface        Winner
# Location
# Adelaide    Hard    Dosedel S.
# Adelaide    Hard    Enqvist T.
# Adelaide    Hard     Escude N.
# Adelaide    Hard    Federer R.
# Adelaide    Hard   Fromberg R.
# ...          ...           ...
# New York    Hard  Nishikori K.
# New York    Hard   Wawrinka S.
# New York    Hard   Djokovic N.
# New York    Hard   Wawrinka S.
# New York    Hard   Wawrinka S.
#
# [38350 rows x 2 columns]

# %% [markdown]
# ### Busquedas que cumplen con varias condiciones

# %%
# buscar torneos de gram slam, que sea con cancha de arcilla, 
# que haya ganado Murray A. y que haya ganado en la final

datos.loc[datos['Series'].str.endswith('Slam') &
                (datos['Surface'] == 'Clay') & 
                (datos['Winner'] == 'Murray A.') & 
                (datos['Round'] == 'Semifinals')]
# Out:
#           ATP   Tournament       Date      Series    Court Surface  \
# Location
# Paris      33  French Open  3/06/2016  Grand Slam  Outdoor    Clay
#
#                Round  Best of     Winner        Loser  ... UBW UBL   LBW  LBL  \
# Location                                               ...
# Paris     Semifinals        5  Murray A.  Wawrinka S.  ... NaN NaN  1.73  2.1
#
#           SJW  SJL  MaxW  MaxL  AvgW  AvgL
# Location
# Paris     NaN  NaN  1.82   2.2  1.75  2.07
#
# [1 rows x 53 columns]

# %%
# buscar torneos realizados en Francia
datos.loc[datos['Tournament'].str.startswith('French')]
# Out:
#           ATP   Tournament        Date      Series    Court Surface  \
# Location
# Paris      32  French Open  29/05/2000  Grand Slam  Outdoor    Clay
# Paris      32  French Open  29/05/2000  Grand Slam  Outdoor    Clay
# Paris      32  French Open  29/05/2000  Grand Slam  Outdoor    Clay
# Paris      32  French Open  29/05/2000  Grand Slam  Outdoor    Clay
# Paris      32  French Open  29/05/2000  Grand Slam  Outdoor    Clay
# ...       ...          ...         ...         ...      ...     ...
# Paris      33  French Open   2/06/2016  Grand Slam  Outdoor    Clay
# Paris      33  French Open   2/06/2016  Grand Slam  Outdoor    Clay
# Paris      33  French Open   3/06/2016  Grand Slam  Outdoor    Clay
# Paris      33  French Open   3/06/2016  Grand Slam  Outdoor    Clay
# Paris      33  French Open   5/06/2016  Grand Slam  Outdoor    Clay
#
#                   Round  Best of       Winner          Loser  ... UBW UBL  \
# ...
