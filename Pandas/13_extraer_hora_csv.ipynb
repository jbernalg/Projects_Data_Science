# %% [markdown]
# ## Extraer hora de un archivo CSV

# %%
# librerias
import pandas as pd
import datetime

# %%
# cargar datos
datos = pd.read_csv('./data/datosnum.csv')
df = pd.DataFrame(datos)

# %%
df
# Out:
#                             A            B                        C  \
# 0      LocalTime=11:18:10.636  Message=TOS  MarketTime=00:00:00.000
# 1      LocalTime=11:18:10.636  Message=TOS  MarketTime=11:17:32.625
# 2      LocalTime=11:18:10.636  Message=TOS  MarketTime=11:17:32.625
# 3      LocalTime=11:18:10.636  Message=TOS  MarketTime=11:17:32.625
# 4      LocalTime=11:18:10.636  Message=TOS  MarketTime=11:17:32.626
# ...                       ...          ...                      ...
# 31748  LocalTime=11:49:35.638  Message=TOS  MarketTime=11:49:39.009
# 31749  LocalTime=11:49:35.638  Message=TOS  MarketTime=11:49:39.009
# 31750  LocalTime=11:49:35.638  Message=TOS  MarketTime=11:49:39.009
# 31751  LocalTime=11:49:35.638  Message=TOS  MarketTime=11:49:39.010
# 31752  LocalTime=11:49:35.769  Message=TOS  MarketTime=11:49:39.064
#
#                    D       E               F         G          H  \
# 0      Symbol=XIV.NQ  Type=1         Price=0    Size=0   Source=0
# ...

# %% [markdown]
# ### Extraer hora

# %%
hora = df['A'].str.extract('((?:[01]\d|2[0-3]):[0-5]\d:[0-5]\d)')
hora
# Out:
#               0
# 0      11:18:10
# 1      11:18:10
# 2      11:18:10
# 3      11:18:10
# 4      11:18:10
# ...         ...
# 31748  11:49:35
# 31749  11:49:35
# 31750  11:49:35
# 31751  11:49:35
# 31752  11:49:35
#
# [31753 rows x 1 columns]
