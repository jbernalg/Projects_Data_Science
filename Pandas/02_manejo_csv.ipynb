# %% [markdown]
# ## Estadistica Basica para un archivo CSV

# %%
# librerias
import pandas as pd
import numpy as np

# %%
# Cargar los datos del csv
datos = pd.read_csv('./data/ATP.csv')
datos.head()
# Out:
# /tmp/ipykernel_8942/3898429576.py:2: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos = pd.read_csv('./data/ATP.csv')
#    ATP  Location                          Tournament       Date  \
# 0    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 1    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 2    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 3    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 4    1  Adelaide  Australian Hardcourt Championships  3/01/2000
#
#           Series    Court Surface      Round  Best of       Winner  ... UBW  \
# 0  International  Outdoor    Hard  1st Round        3   Dosedel S.  ... NaN
# 1  International  Outdoor    Hard  1st Round        3   Enqvist T.  ... NaN
# 2  International  Outdoor    Hard  1st Round        3    Escude N.  ... NaN
# 3  International  Outdoor    Hard  1st Round        3   Federer R.  ... NaN
# ...

# %%
# Informacion sobre los datos
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46652 entries, 0 to 46651
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ATP         46652 non-null  int64
#  1   Location    46652 non-null  object
#  2   Tournament  46652 non-null  object
#  3   Date        46652 non-null  object
#  4   Series      46652 non-null  object
#  5   Court       46652 non-null  object
#  6   Surface     46652 non-null  object
#  7   Round       46652 non-null  object
#  8   Best of     46652 non-null  int64
#  9   Winner      46652 non-null  object
#  10  Loser       46652 non-null  object
#  11  WRank       46637 non-null  object
#  12  LRank       46581 non-null  object
#  13  W1          46423 non-null  float64
#  14  L1          46423 non-null  float64
#  15  W2          45962 non-null  float64
#  16  L2          45963 non-null  float64
#  17  W3          21365 non-null  float64
#  18  L3          21365 non-null  float64
# ...

# %%
# mostrar solo n registros 
datos.head(5)
# Out:
#    ATP  Location                          Tournament       Date  \
# 0    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 1    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 2    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 3    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 4    1  Adelaide  Australian Hardcourt Championships  3/01/2000
#
#           Series    Court Surface      Round  Best of       Winner  ... UBW  \
# 0  International  Outdoor    Hard  1st Round        3   Dosedel S.  ... NaN
# 1  International  Outdoor    Hard  1st Round        3   Enqvist T.  ... NaN
# 2  International  Outdoor    Hard  1st Round        3    Escude N.  ... NaN
# 3  International  Outdoor    Hard  1st Round        3   Federer R.  ... NaN
# 4  International  Outdoor    Hard  1st Round        3  Fromberg R.  ... NaN
#
#   UBL LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL
# 0 NaN NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# ### Estadistica de los datos

# %%
datos.describe()
# aplica para 42 variables de las 54 debido a que son de tipo numerico
# Out:
#                 ATP       Best of            W1            L1            W2  \
# count  46652.000000  46652.000000  46423.000000  46423.000000  45962.000000
# mean      32.931000      3.373746      5.792667      4.043211      5.772856
# std       17.953268      0.780315      1.239261      1.847833      1.253846
# min        1.000000     -1.000000      0.000000      0.000000      0.000000
# 25%       19.000000      3.000000      6.000000      3.000000      6.000000
# 50%       33.000000      3.000000      6.000000      4.000000      6.000000
# 75%       49.000000      3.000000      6.000000      6.000000      6.000000
# max       69.000000      5.000000      7.000000      7.000000      7.000000
#
#                  L2            W3            L3           W4           L4  \
# count  45963.000000  21365.000000  21365.000000  4226.000000  4226.000000
# mean       3.853621      6.018254      3.592745     5.777094     3.871510
# ...

# %% [markdown]
# ### Sustituir valores faltantes

# %%
df = pd.DataFrame(datos)

# %%
df = df.replace(np.nan, '0')
df = df.replace('N/A', '0')
df = df.replace('NR', '0')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46652 entries, 0 to 46651
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ATP         46652 non-null  int64
#  1   Location    46652 non-null  object
#  2   Tournament  46652 non-null  object
#  3   Date        46652 non-null  object
#  4   Series      46652 non-null  object
#  5   Court       46652 non-null  object
#  6   Surface     46652 non-null  object
#  7   Round       46652 non-null  object
#  8   Best of     46652 non-null  int64
#  9   Winner      46652 non-null  object
#  10  Loser       46652 non-null  object
#  11  WRank       46652 non-null  object
#  12  LRank       46652 non-null  object
#  13  W1          46652 non-null  object
#  14  L1          46652 non-null  object
#  15  W2          46652 non-null  object
#  16  L2          46652 non-null  object
#  17  W3          46652 non-null  object
#  18  L3          46652 non-null  object
# ...

# %% [markdown]
# ### Estadisiticas de los datos sin NaN

# %%
df.describe()
# solo toma dos variables porque son de tipo numerico
# Out:
#                 ATP       Best of
# count  46652.000000  46652.000000
# mean      32.931000      3.373746
# std       17.953268      0.780315
# min        1.000000     -1.000000
# 25%       19.000000      3.000000
# 50%       33.000000      3.000000
# 75%       49.000000      3.000000
# max       69.000000      5.000000

# %% [markdown]
# ### Nombre de las variables

# %%
# Con list. Muestra los nombres en formato de lista: 1 nombre por fila
list(df)
# Out:
# ['ATP',
#  'Location',
#  'Tournament',
#  'Date',
#  'Series',
#  'Court',
#  'Surface',
#  'Round',
#  'Best of',
#  'Winner',
#  'Loser',
#  'WRank',
#  'LRank',
#  'W1',
#  'L1',
#  'W2',
#  'L2',
#  'W3',
#  'L3',
#  'W4',
#  'L4',
#  'W5',
#  'L5',
#  'Wsets',
#  'Lsets',
#  'Comment',
#  'CBW',
#  'CBL',
#  'GBW',
#  'GBL',
#  'IWW',
#  'IWL',
#  'SBW',
#  'SBL',
#  'B365W',
#  'B365L',
#  'B&WW',
#  'B&WL',
#  'EXW',
#  'EXL',
#  'PSW',
#  'PSL',
#  'WPts',
#  'LPts',
#  'UBW',
#  'UBL',
#  'LBW',
#  'LBL',
#  'SJW',
#  'SJL',
#  'MaxW',
#  'MaxL',
#  'AvgW',
#  'AvgL']

# %%
# con el metodo columns. Muestra los dato en formato de lista continua: un dato seguido del otro
df.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'W1', 'L1',
#        'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets',
#        'Comment', 'CBW', 'CBL', 'GBW', 'GBL', 'IWW', 'IWL', 'SBW', 'SBL',
#        'B365W', 'B365L', 'B&WW', 'B&WL', 'EXW', 'EXL', 'PSW', 'PSL', 'WPts',
#        'LPts', 'UBW', 'UBL', 'LBW', 'LBL', 'SJW', 'SJL', 'MaxW', 'MaxL',
#        'AvgW', 'AvgL'],
#       dtype='object')

# %% [markdown]
# ### Convertir variables tipo objects a numericas

# %%
df['Wsets'] = df.Wsets.astype(int)
df['WRank'] = df.WRank.astype(int)
df.describe()
# Out:
#                 ATP       Best of         WRank         Wsets
# count  46652.000000  46652.000000  46652.000000  46652.000000
# mean      32.931000      3.373746     59.035926      2.133092
# std       17.953268      0.780315     73.296447      0.481388
# min        1.000000     -1.000000      0.000000      0.000000
# 25%       19.000000      3.000000     17.000000      2.000000
# 50%       33.000000      3.000000     41.000000      2.000000
# 75%       49.000000      3.000000     77.000000      2.000000
# max       69.000000      5.000000   1890.000000      3.000000

# %% [markdown]
# ### Numero de Registros en el DataFrame

# %%
df.size
# Out:
# 2519208

# %% [markdown]
# ### Numero de Filas y Columnas del DataFrame

# %%
df.shape
# Out:
# (46652, 54)

# %% [markdown]
# ### Dimension del DataFrame

# %%
df.ndim
# 1 para series que solo consta de filas
# 2 para DataFrames o datos bidimensionales
# Out:
# 2

# %% [markdown]
# ### Eliminar registros que contengan valores faltantes

# %%
# Tipo de datos de la columna con valores a eliminar
df['LBL'].dtypes
# Out:
# dtype('O')

# %%
# eliminar todos lo registros que tenga 0 como valor en la columna LBL
df.drop(df[df['LBL'] == '0'].index, inplace=True)
df.head()
# Out:
#        ATP Location    Tournament        Date         Series    Court Surface  \
# 23173    2  Chennai  Chennai Open  31/12/2007  International  Outdoor    Hard
# 23174    2  Chennai  Chennai Open  31/12/2007  International  Outdoor    Hard
# 23175    2  Chennai  Chennai Open  31/12/2007  International  Outdoor    Hard
# 23177    2  Chennai  Chennai Open  31/12/2007  International  Outdoor    Hard
# 23178    2  Chennai  Chennai Open   1/01/2008  International  Outdoor    Hard
#
#            Round  Best of       Winner  ...   UBW   UBL    LBW    LBL SJW SJL  \
# 23173  1st Round        3   Malisse X.  ...  1.52  2.45  1.444  2.625   0   0
# 23174  1st Round        3    Melzer J.  ...   1.5   2.5  1.444  2.625   0   0
# 23175  1st Round        3     Serra F.  ...  1.45  2.68  1.444  2.625   0   0
# 23177  1st Round        3   Youzhny M.  ...  1.13   5.6  1.125    5.5   0   0
# 23178  1st Round        3  Eschauer W.  ...  1.45  2.68  1.444  2.625   0   0
#
#       MaxW MaxL AvgW AvgL
# ...

# %%
datos.dropna(how='any', inplace=True)
datos
#elimina todas las filas debido a que todas tienen valores faltantes
# Out:
# Empty DataFrame
# Columns: [ATP, Location, Tournament, Date, Series, Court, Surface, Round, Best of, Winner, Loser, WRank, LRank, W1, L1, W2, L2, W3, L3, W4, L4, W5, L5, Wsets, Lsets, Comment, CBW, CBL, GBW, GBL, IWW, IWL, SBW, SBL, B365W, B365L, B&WW, B&WL, EXW, EXL, PSW, PSL, WPts, LPts, UBW, UBL, LBW, LBL, SJW, SJL, MaxW, MaxL, AvgW, AvgL]
# Index: []
#
# [0 rows x 54 columns]
