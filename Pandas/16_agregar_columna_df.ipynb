# %% [markdown]
# ## Agregar una columna a un DataFrame

# %%
#librerias
import pandas as pd

# %%
# cargar datos
datos = pd.read_csv('./data/energy.csv', header=0) # header 0 indica que la primera linea se toma como nombre de las columnas
df = pd.DataFrame(datos)
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %% [markdown]
# ### Convertir a Kelvin los grados de T1

# %%
Tk = df['T1'] + 273.15

# asignar los valores de Tk en una nueva columna
df = df.assign(kelvin=Tk.values)

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  19.79  44.730000  19.000000  ...  45.53  6.600000        733.5    92.0
# 1  19.79  44.790000  19.000000  ...  45.56  6.483333        733.6    92.0
# 2  19.79  44.933333  18.926667  ...  45.50  6.366667        733.7    92.0
# 3  19.79  45.000000  18.890000  ...  45.40  6.250000        733.8    92.0
# 4  19.79  45.000000  18.890000  ...  45.40  6.133333        733.9    92.0
#
# ...

# %% [markdown]
# ### Guardar resultados en archivo csv

# %%
df.to_csv('Energy2.csv', sep='\t')
