# %% [markdown]
# # Lista
# Una lista es una estructura de datos ordenada. En otras palabras, es un tipo de dato conformado por múltiples datos. Una lista se crea utilizando corchetes ([ ]) y separando cada dato almacenado a través de comas (,). Los datos almacenados pueden ser de cualquier tipo (incluso pueden ser una misma lista).

# %%
['hola', 2 + 9, 3.1415, False, 9 > 2]
# Out:
# ['hola', 11, 3.1415, False, True]

# %% [markdown]
# ## Subíndice
# Una lista suele interpretarse como una fila de casillas, en donde cada casilla se almacena un elemento. Cada una de las casillas se identifica con un valor de una secuencia de números. Cada valor se conoce como subíndice.
#
# El primer elemento le corresponde el subíndice 0, el segundo elemento le corresponde el índice 1..., el enésimo elemento le corresponde el índice n-1.

# %%
terminos = ['a','c', 'Hello', 18, True]
len(terminos)
# Out:
# 5

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
frutas = ['manzana', 'durazno', 'pera', 'piña']

# %% [markdown]
# Para acceder a un elemento de la lista `frutas`, debemos:
#
#
# 1.   Llamar a la variable que referencia a la lista.
# 2.   Utilizar corchetes ([ ]) y, dentro de los corchetes, indicar el subíndice del elemento al que queremos acceder.
#
# Intentemos acceder a `'durazno'`.

# %%
frutas[1]
# Out:
# 'durazno'

# %% [markdown]
# También podemos utilizar subíndices con valores negativos.
#
# Los subíndices negativos referencian a los elementos de la lista en reversa. -1 indica el último elemento de la lista, -2 el penúltimo..., y `-n` el primer elemento de la lista, siendo `n` el número de elementos de la lista.

# %%
frutas[-4]
# Out:
# 'manzana'

# %%
frutas[-1]
# Out:
# 'piña'

# %% [markdown]
# ## Modificar elementos
# Para cambiar el dato almacenado en un subíndice de la lista, utilizamos la misma sintaxis de acceso acompañado del operador de asignación (=) y el valor a asignar.

# %%
frutas
# Out:
# ['manzana', 'durazno', 'pera', 'piña']

# %%
frutas[1] = 'papaya'
frutas
# Out:
# ['manzana', 'papaya', 'pera', 'piña']

# %% [markdown]
# ## Agregar datos

# %% [markdown]
# ### Método append
# Para agregar un dato a una lista, utilizamos el método `append`. El método `append` recibe como argumento el dato a agregar, aumenta el tamaño de la lista y agrega el nuevo dato como su último elemento.

# %%
frutas
# Out:
# ['manzana', 'papaya', 'pera', 'piña']

# %%
frutas.append('maracuyá')
frutas
# Out:
# ['manzana', 'papaya', 'pera', 'piña', 'maracuyá']

# %% [markdown]
# ### Método extend
# El método `extend` nos permite añadir múltiples datos a través de una lista. `extend` recibe como argumento una lista que contiene los datos a agregar.

# %%
frutas
# Out:
# ['manzana', 'papaya', 'pera', 'piña', 'maracuyá']

# %%
frutas.extend(['naranja', 'ciruela'])
frutas
# Out:
# ['manzana', 'papaya', 'pera', 'piña', 'maracuyá', 'naranja', 'ciruela']

# %% [markdown]
# También podemos añadir múltiples datos utilizando el operador de asignación suma (+=), con los nuevos datos introducidos en otra lista.

# %%
frutas += ['kiwi', 'mandarina']
frutas
# Out:
# ['manzana',
#  'papaya',
#  'pera',
#  'piña',
#  'maracuyá',
#  'naranja',
#  'ciruela',
#  'kiwi',
#  'mandarina']

# %% [markdown]
# ## Eliminar datos
# Al momento de eliminar un dato de la lista, esta se **reacomodará**.
#
# Con la reacomodación, el tamaño de la lista se verá reducido en uno y los elementos ubicados a la derecha del dato eliminado cambiarán su subíndice.
#
# Por ejemplo, si eliminamos el dato `'pera'` de `frutas`, el tamaño de la lista cambiará a `6` y el nuevo subíndice de `'piña'` será 2, el de `'maracuyá'` 3, y así sucesivamente.
#
# Para remover un dato de una lista tenemos varias alternativas.

# %% [markdown]
# ### Sentencia del
# Podemos utilizar la sentencia `del` acompañada del dato accedido a través del subíndice.

# %%
frutas
# Out:
# ['manzana',
#  'papaya',
#  'pera',
#  'piña',
#  'maracuyá',
#  'naranja',
#  'ciruela',
#  'kiwi',
#  'mandarina']

# %%
del frutas[2]
frutas
# Out:
# ['manzana',
#  'papaya',
#  'piña',
#  'maracuyá',
#  'naranja',
#  'ciruela',
#  'kiwi',
#  'mandarina']

# %% [markdown]
# ### Método remove
# El método `remove` nos ayuda a eliminar un dato. `remove` recibirá como argumento el dato a eliminar.

# %%
frutas
# Out:
# ['manzana',
#  'papaya',
#  'piña',
#  'maracuyá',
#  'naranja',
#  'ciruela',
#  'kiwi',
#  'mandarina']

# %%
frutas.remove('maracuyá')
frutas
# Out:
# ['manzana', 'papaya', 'piña', 'naranja', 'ciruela', 'kiwi', 'mandarina']

# %% [markdown]
# Si existe uno o más datos del mismo valor, `remove` eliminará el dato ubicado en el menor subíndice.

# %%
frutas += ['kiwi', 'maracuyá']
frutas
# Out:
# ['manzana',
#  'papaya',
#  'piña',
#  'naranja',
#  'ciruela',
#  'kiwi',
#  'mandarina',
#  'kiwi',
#  'maracuyá']

# %%
frutas.remove('kiwi')
frutas
# Out:
# ['manzana',
#  'papaya',
#  'piña',
#  'naranja',
#  'ciruela',
#  'mandarina',
#  'kiwi',
#  'maracuyá']

# %% [markdown]
# ### Método pop
# El método `pop` nos ayuda a eliminar un dato a través de su subíndice. `pop` recibirá como argumento el **subíndice** que indica el dato a eliminar y devolverá como valor el dato eliminado.

# %%
frutas
# Out:
# ['manzana',
#  'papaya',
#  'piña',
#  'naranja',
#  'ciruela',
#  'mandarina',
#  'kiwi',
#  'maracuyá']

# %%
valor_eliminado = frutas.pop(3)
print(f'el valor eliminado fue {valor_eliminado}')
# Out:
# el valor eliminado fue naranja

# %%
frutas.pop(0)
frutas
# Out:
# ['papaya', 'piña', 'ciruela', 'mandarina', 'kiwi', 'maracuyá']

# %% [markdown]
# ## Secciones de lista
# Podemos crear "secciones" o sublistas a partir de una lista existente.
#
# Una sublista es una lista que se crea a partir de otra lista. Al crearse, siempre tendrá elementos en común con la lista "padre".
#
# Su sintaxis es similar a la de acceder un dato.

# %%
frutas
# Out:
# ['papaya', 'piña', 'ciruela', 'mandarina', 'kiwi', 'maracuyá']

# %%
frutas[2:4]
# Out:
# ['ciruela', 'mandarina']

# %% [markdown]
# Una sublista tiene una posición inicial y una posición final. Así que, en lugar de indicar un único valor numérico en los corchetes, debemos indicarlo de la siguiente manera:
#
# 1.   subíndice del primer elemento de la sublista
# 2.   operador dos puntos (:)
# 3.   subíndice del `último-1` elemento de la sublista
#
# Esto quiere decir que el primer valor es **inclusivo** y el último valor es **exclusivo**.
#
# En la celda anterior, la sintaxis fue la siguiente:
#
# *   2
# *   :
# *   4
#
# Si restamos el segundo valor con el primer valor `(4 - 2)`, obtenemos la cantidad de elementos de la sublista (si tienen el mismo signo). En este caso, fueron dos: `'ciruela'` y `'mandarina'`.

# %%
frutas[1:5]
# Out:
# ['piña', 'ciruela', 'mandarina', 'kiwi']

# %%
frutas[3:7]
# Out:
# ['mandarina', 'kiwi', 'maracuyá']

# %% [markdown]
# Podemos omitir el primer subíndice. En este caso, tomará como valor por defecto `0`.

# %%
frutas[:2]
# Out:
# ['papaya', 'piña']

# %%
frutas[0:2]
# Out:
# ['papaya', 'piña']

# %% [markdown]
# También podemos omitir el último subíndice. Este tomará como valor por defecto la cantidad de elementos de la lista padre.

# %%
frutas[3:]
# Out:
# ['mandarina', 'kiwi', 'maracuyá']

# %%
frutas[3:6]
# Out:
# ['mandarina', 'kiwi', 'maracuyá']

# %% [markdown]
# Incluso, ¡podemos omitir ambos valores y tendrán los mismos valores por defecto! Lo que quiere decir que generará una sublista con los mismos elementos de la lista.

# %%
frutas[:]
# Out:
# ['papaya', 'piña', 'ciruela', 'mandarina', 'kiwi', 'maracuyá']

# %%
frutas[0:]
frutas
# Out:
# ['papaya', 'piña', 'ciruela', 'mandarina', 'kiwi', 'maracuyá']

# %% [markdown]
# Podemos utilizar valores negativos en la sintaxis. Y también accederá a los elementos de forma inversa.

# %%
frutas[-1:]
# Out:
# ['maracuyá']

# %%
frutas[-5:-2]
# Out:
# ['piña', 'ciruela', 'mandarina']

# %%
frutas[-5:4]
# Out:
# ['piña', 'ciruela', 'mandarina']

# %% [markdown]
# Si a la sintaxis `[:]` añadimos otro operador dos puntos (:) y un valor numérico, se determinará la secuencia que utilizará la sublista para añadir los elementos. Por ejemplo, `[::2]` tendrá en cuenta todos los elementos de la lista y los añadirá a la sublista de dos en dos.

# %%
frutas[::2]
# Out:
# ['papaya', 'ciruela', 'kiwi']

# %% [markdown]
# Cualquier secuencia puede utilizar la sintaxis de secciones, como el *string*.

# %%
'Callejón'[:5]
# Out:
# 'Calle'

# %% [markdown]
# ## Recorrido de listas
# Como una lista es una secuencia de elementos, podemos recorrerla a través de `for`.

# %%
frutas
# Out:
# ['papaya', 'piña', 'ciruela', 'mandarina', 'kiwi', 'maracuyá']

# %%
for i in frutas:
  print(i)
# Out:
# papaya
# piña
# ciruela
# mandarina
# kiwi
# maracuyá

# %% [markdown]
# Podemos usar la función `enumerate` para referir el número y el elemento de la secuencia de la iteración actual.

# %%
for i in enumerate(frutas):
  print(i)
# Out:
# (0, 'papaya')
# (1, 'piña')
# (2, 'ciruela')
# (3, 'mandarina')
# (4, 'kiwi')
# (5, 'maracuyá')

# %% [markdown]
# Podemos asignar este valor numérico a otra variable iteradora en `for`.

# %%
for indice, fruta in enumerate(frutas):
  print(f'El elemento número {indice} es {fruta}')
# Out:
# El elemento número 0 es papaya
# El elemento número 1 es piña
# El elemento número 2 es ciruela
# El elemento número 3 es mandarina
# El elemento número 4 es kiwi
# El elemento número 5 es maracuyá
